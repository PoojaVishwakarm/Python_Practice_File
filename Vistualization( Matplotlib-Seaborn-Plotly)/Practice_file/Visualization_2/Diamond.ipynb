# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dia=pd.read_csv("diamonds.csv")
dia
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
dia.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %% [markdown]
# # Basic Plots using Matplotlib

# %%
plt.plot(dia['carat'],dia['price'])
plt.title('Carat vs Price Line Plot')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.show()

# %%
# Scatter Plot
plt.scatter(dia['carat'],dia['price'])
plt.title('Carat vs Peice Scatter Plot')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.show()

# %%
# bar plot 
plt.bar(dia['cut'].unique(),dia.groupby('cut')['price'].mean())
plt.title('Average Price by cut')
plt.xlabel('cut')
plt.ylabel('Average Price')
plt.show()

# %% [markdown]
# # Intermediate Plots using Matplotlib

# %%
# Histograma
plt.hist(dia['price'],bins=10,edgecolor='black')
plt.title('Distribution of Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
# Box plot 
plt.boxplot(dia['carat'],vert=False)
plt.title('Bos plot of carat')
plt.xlabel('Carat')
plt.show()

# %%
# pie Chart 
cut_counts=dia['cut'].value_counts()
plt.pie(cut_counts, labels=cut_counts.index,autopct='%1.1f%%',startangle=90)
plt.title('Distribution of cut Quality')
plt.show()

# %% [markdown]
# # Advanced Plot using Matplotlib

# %%
#  heatMap of correlation matrix
correlation=dia[['carat', 'depth', 'table', 'price', 'x', 'y', 'z']].corr()
plt.imshow(correlation,cmap='coolwarm',interpolation='none')
plt.colorbar()
plt.xticks(range(len(correlation)),correlation.columns,rotation=90)
plt.yticks(range(len(correlation)),correlation.columns)
plt.title('HeatMap of correction Matrix')
plt.show()

# %%
sns.heatmap(correlation,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
# subplots 
fig,axes=plt.subplots(1,2,figsize=(12,5))
axes[0].hist(dia['carat'],bins=10,edgecolor='black')
axes[0].set_title('Histogrm of carat')
axes[1].hist(dia['price'],bins=10,edgecolor='black')
axes[1].set_title('Histogram of price')
plt.show()

# %%
fig,axes=plt.subplots(2,2,figsize=(12,10))
axes[0,0].hist(dia['carat'],bins=10,edgecolor='black')
axes[0,0].set_title('histogram of carat')
axes[0,1].hist(dia['price'], bins=10,edgecolor='black')
axes[0,1].set_title('Histogram of price')
axes[1,0].scatter(dia['carat'],dia['price'])
axes[1,0].set_title('carat vs price scatterr plot')
axes[1,0].set_xlabel('carat')
axes[1,0].set_ylabel('Price')
axes[1,1].bar(dia['cut'].unique(),dia.groupby('cut')['price'].mean())
axes[1,1].set_title('average Price by cut')
axes[1,1].set_xlabel('cut')
plt.show()

# %% [markdown]
# # Basic Plots using seaborn

# %%
# seaborn scatter plot 
sns.scatterplot(x='carat',y='price', data=dia)
plt.title('seaborn scatter plot of carat vs Price')
plt.show()

# %%
sns.scatterplot(x='carat',y='price',data=dia,hue='cut')
plt.title("Seaborn scatter plot of carat vs price")
plt.show()

# %%
# seaborn Line Plot
sns.lineplot(x='carat',y='price',data=dia)
plt.title('Seaborn line plot of carat vs price')
plt.show()

# %%
sns.lineplot(x='carat',y='price',data=dia,hue='cut')
plt.title('Seaborn line plot of carat vs price')
plt.show()

# %%
figure=plt.figure(figsize=(12,6))
sns.lineplot(x='carat',y='price',data=dia,hue='cut')
plt.title('seabborn line plot of carat vs Price')
plt.show()

# %%
# Seaborn line Plot with Facets based on cu column
g=sns.FacetGrid(dia,col='cut',col_wrap=3,height=4,hue='cut')
g.map(sns.lineplot,'carat','price')
g.add_legend()
plt.show()

# %% [markdown]
# # Intermediate Plots using Seaborn

# %%
# Box Plot 
sns.boxplot(x='cut',y='price',data=dia)
plt.title('Box plot of price by cut')
plt.show()

# %%
# box plot 
sns.boxplot(x='cut',y='price',data=dia,hue='color')
plt.title('Box plot of price by cut')
plt.show()

# %%
figure=plt.figure(figsize=(12,5))
sns.boxplot(x='cut',y='price',data=dia,hue='color')
plt.title('Box plot of price by cut')
plt.show()

# %%
# violin plot 
sns.violinplot(x='color',y='price', data=dia)
plt.title('violin plot of price by color')
plt.show()

# %%
# Count plot 
sns.countplot(x='cut',data=dia)
plt.title('count plot of cut')
plt.show()

# %%
sns.countplot(x='cut',data=dia,hue='color')
plt.title('Count plot of cut')
plt.show()

# %% [markdown]
# # Advanced Plots using Seaborn

# %%
# heatmap 
sns.heatmap(dia[['carat','depth','table','price','x','y','z']].corr(),annot=True,cmap='coolwarm')
plt.title('Seaborn heatmap of correlation matrix')
plt.show()

# %%
sns.pairplot(dia,hue='cut')
plt.title('pair plot of diamond attributes')
plt.show()

# %%
# facegrid
g=sns.FacetGrid(dia,col='color',col_wrap=3)
g.map(plt.hist,'price',bins=10,edgecolor='black')
plt.show()

# %% [markdown]
# # Enhancing plots with seaborn for Report_ready Visualization

# %% [markdown]
# ###  Setting Seaborn Styles and Contexts

# %%
# Setting Seaborn Style 

sns.set_style('whitegrid') # options: white ,dark,whitegrid, darkgrid ,ticks
sns.set_context('notebook') # Options: paper,notebook,talk,poster

# Example plot with updated style 

sns.scatterplot(x='carat',y='price',data=dia)
plt.title('scatter plot with whitegrid style and notebook context')
plt.show()

# %%
# using a dark background style 
sns.set_style('dark')
sns.lineplot(x='carat',y='price',data=dia)
plt.title('Line plot with Dark BackGround Style')
plt.show()

# %%
# Customizing the font scale 
sns.set_context('talk',font_scale=0.5)
sns.boxplot(x='cut',y='price',data=dia)
plt.title('Box plot with talk context and larger font scale')
plt.show()

# %%
# using  a predefined color palette 
sns.set_palette('colorblind') # option : deep , muted , bright, pastel, dark, colorblind
sns.violinplot(x='color', y='price',data=dia)
plt.title('violin plot with pastel color palette')
plt.show()

# %%
# using predofined  color palette 
figure=plt.figure(figsize=(12,4))
sns.set_context('notebook')
sns.set_palette('pastel')
sns.violinplot(x='color',y='price',data=dia,hue='cut')
plt.title("violin plot with pastel color palatte")
plt.show()

# %%
# Creating and using a custom color palette 
custom_palette=sns.color_palette(['#FF5733','#33FFCE','#335BFF','#FF33A1','#9B33FF'])
sns.set_palette(custom_palette)
sns.countplot(x='cut',data=dia,hue='color')
plt.title("Count plot with custom Color Palette")
plt.show()

# %%
# Adding Gridlines to the background 
sns.set_style('whitegrid')
sns.scatterplot(x='carat',y='price',data=dia)
plt.grid(True,linestyle='--',alpha=0.5)
plt.title('Scatter plot with gridlines')
plt.show()

# %%
# Removing spines from the plot for a cleaner look 
sns.set_style('white')
ax=sns.histplot(dia['price'],bins=10,edgecolor='black')
sns.despine()
plt.title('Histogram with Spines Removed ')
plt.show()

# %% [markdown]
# ## Adding Annotations and Legends

# %%
# Adding annotations to a scatter plot 
sns.scatterplot(x='carat',y='price',data=dia)
plt.title('Scatter plot with annotations')
for i in range(len(dia)):
    plt.annotate(f"${dia['price'][i]}",(dia['carat'][i],dia['price'][i]),fontsize=8,alpha=0.7)
plt.show()

# %%
# Customing the legend 
figure=plt.figure(figsize=(12,3))
sns.boxplot(x='cut',y='price',data=dia)
plt.legend(title='Cut Types',labels=dia['cut'].unique(),loc='upper right',bbox_to_anchor=(0,1),frameon=True)
plt.title('Box plot with Custom legend')
plt.show()

# %% [markdown]
# # Using Facetgrid for multi-panel plots

# %%
# FacetGrid  for multiple histogram based on cut
g=sns.FacetGrid(dia,col='cut',col_wrap=3,height=4)
g.map(plt.hist,'price',bins=10,edgecolor='black')
g.set_titles("{col_name} Cut")
plt.show()

# %%
fig=plt.figure(figsize=(12,6))
# using Facetgrid with scatter plots and hue 
g=sns.FacetGrid(dia,hue='color',height=5)
g.map(plt.scatter,'carat','price').add_legend()
plt.title('Facetgrid scatter plot with hue')
plt.show()

# %% [markdown]
# ## Fine -Turing Axis Labela and Titles

# %%
# T=Rotating x-axix label for better readability
sns.barplot(x='color',y='price',data=dia)
plt.xticks(rotation=45)
plt.title("Bar plot with rotated X-axis Labels")
plt.show()

# %%
# Adjusting the y-axis scale 
sns.histplot(dia['price'],bins=10,edgecolor='black')
plt.yscale('log')
plt.title('histogram with logarithmic  y-axis ')
plt.show()

# %%
# Adjusting the y-axis scale 
sns.histplot(dia['price'],bins=10,edgecolor='black')
plt.title('histogram with logarithmic  y-axis ')
plt.show()

# %% [markdown]
# ## Using Seaborn The Ticks Theme

# %%
# Applying the ticks theme 
figure=plt.figure(figsize=(12,4))
sns.set_theme(style='ticks',palette='muted',context='notebook',font_scale=1.5)
sns.lineplot(x='carat',y='price',data=dia)
sns.despine() # Remove spines for a cleaner look
plt.title('line plot with ticks theme and muted palatte')
plt.show()

# %%
# using the darkgrid theme for bar plots
sns.set_theme(style='darkgrid')
sns.barplot(x='cut',y='price',data=dia)
plt.title('bar plot with darkgrid theme')
plt.show()

# %%
# Saving the refined plot to a file 
sns.set_style('whitegrid')
sns.scatterplot(x='carat',y='price',data=dia)
plt.title('Scatter plot ready for reports')
plt.savefig('scatter.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
import seaborn as sns
palettes=sns.palettes.SEABORN_PALETTES
print(palettes)
# Out:
# {'deep': ['#4C72B0', '#DD8452', '#55A868', '#C44E52', '#8172B3', '#937860', '#DA8BC3', '#8C8C8C', '#CCB974', '#64B5CD'], 'deep6': ['#4C72B0', '#55A868', '#C44E52', '#8172B3', '#CCB974', '#64B5CD'], 'muted': ['#4878D0', '#EE854A', '#6ACC64', '#D65F5F', '#956CB4', '#8C613C', '#DC7EC0', '#797979', '#D5BB67', '#82C6E2'], 'muted6': ['#4878D0', '#6ACC64', '#D65F5F', '#956CB4', '#D5BB67', '#82C6E2'], 'pastel': ['#A1C9F4', '#FFB482', '#8DE5A1', '#FF9F9B', '#D0BBFF', '#DEBB9B', '#FAB0E4', '#CFCFCF', '#FFFEA3', '#B9F2F0'], 'pastel6': ['#A1C9F4', '#8DE5A1', '#FF9F9B', '#D0BBFF', '#FFFEA3', '#B9F2F0'], 'bright': ['#023EFF', '#FF7C00', '#1AC938', '#E8000B', '#8B2BE2', '#9F4800', '#F14CC1', '#A3A3A3', '#FFC400', '#00D7FF'], 'bright6': ['#023EFF', '#1AC938', '#E8000B', '#8B2BE2', '#FFC400', '#00D7FF'], 'dark': ['#001C7F', '#B1400D', '#12711C', '#8C0800', '#591E71', '#592F0D', '#A23582', '#3C3C3C', '#B8850A', '#006374'], 'dark6': ['#001C7F', '#12711C', '#8C0800', '#591E71', '#B8850A', '#006374'], 'c
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Function to display all available seaborn color palettes
def display_palette():
    palette_names = sorted(sns.palettes.SEABORN_PALETTES)  # get palette names
    n = len(palette_names)

    # Create subplots
    fig, axes = plt.subplots(nrows=n, figsize=(8, 2 * n))

    for ax, palette_name in zip(axes, palette_names):
        colors = sns.color_palette(palette_name)
        for i, color in enumerate(colors):
            ax.add_patch(plt.Rectangle((i, 0), 1, 1, color=color))
        ax.set_xlim(0, len(colors))
        ax.set_ylim(0, 1)
        ax.set_title(palette_name, fontsize=10, pad=10)
        ax.axis("off")

    plt.tight_layout()
    plt.show()


# Call the function
display_palette()
