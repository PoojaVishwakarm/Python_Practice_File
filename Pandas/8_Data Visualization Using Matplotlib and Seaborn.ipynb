# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data_sales=pd.read_excel('Dataset/linechart.xlsx')
data_sales
# Out:
#    Quarter  Fridge  Dishwasher  Washing Machine
# 0  Q1 2022    12.5         8.0              9.2
# 1  Q2 2022    11.0         7.5              8.5
# 2  Q3 2022    13.2         9.0              7.5
# 3  Q4 2022    16.4        11.0              7.6
# 4  Q1 2023    13.8         9.5              6.8
# 5  Q2 2023    14.0         8.0              6.0

# %%
plt.figure(figsize=(12,4))
plt.plot(data_sales['Quarter'],data_sales['Fridge'])
plt.plot(data_sales['Quarter'],data_sales['Dishwasher'])
plt.plot(data_sales['Quarter'],data_sales['Washing Machine'])
plt.show()
